# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
#import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
#import the data
data_features_train = pd.read_csv('train_features.csv',index_col='pid').sort_values(by=['pid', 'Time'])
data_features_test = pd.read_csv('test_features.csv',index_col='pid').sort_values(by=['pid', 'Time'])
data_labels_train = pd.read_csv('train_labels.csv', index_col='pid').sort_values(by=['pid'])


vitals = ['LABEL_RRate', 'LABEL_ABPm', 'LABEL_SpO2', 'LABEL_Heartrate']
tests = ['LABEL_BaseExcess', 'LABEL_Fibrinogen', 'LABEL_AST', 'LABEL_Alkalinephos', 'LABEL_Bilirubin_total',
         'LABEL_Lactate', 'LABEL_TroponinI', 'LABEL_SaO2',
         'LABEL_Bilirubin_direct', 'LABEL_EtCO2']
sepsis = ['LABEL_Sepsis']

# %%
def feature_engineering(df):
    df_pop_mean = df.drop(['Age'], axis=1).mean()
    #construct the features
    
    df_age = df['Age'].groupby(by='pid', dropna=False).mean() #this is a bit hackerboy method lmao
    
    df_mean = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).mean()
    df_var = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).var()
    df_min = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).min()
    df_max = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).max()
    df_first = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).first()
    df_last = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).last()
    df_nan_count = df.drop(['Age'], axis=1).groupby(by='pid', dropna=False).count()
    #df_last_observed_value = df.groupby(by='pid', dropna=False)
    #df_first_observed_value
    
    
    
    #impute missing values
    df_mean.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    df_var.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    df_min.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    df_max.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    df_first.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    df_last.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    #df_last_observed_value.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    #df_first_observed_value.fillna({col:df_pop_mean[col] for col in df.drop(['Age'], axis=1).columns}, inplace=True)
    
    df_features = pd.concat([df_age, df_mean.add_suffix('_mean'), df_var.add_suffix('_var'),
                             df_min.add_suffix('_min'), df_max.add_suffix('_max'), df_first.add_suffix('_first'),
                             df_last.add_suffix('_last'), df_nan_count.add_suffix('_nan_count')], axis=1)
    return df_features

# %%
#set up features, took most correlated ones for each of 'RRate', 'ABPm', 'SpO2', 'Heartrate'

features_3 = ['Age','Temp', 'Lactate', 'ABPs', 'Chloride', 'Hgb', 'pH', 'ABPd', 'RRate', 'ABPm', 'SpO2', 'Heartrate']

X_3_train = feature_engineering(data_features_train[features_3]).to_numpy()
X_3_test = feature_engineering(data_features_test[features_3]).to_numpy()
y_3_train = data_labels_train[vitals].to_numpy()

# %%
# Define a pipeline to search for the best hyperparameters for ridge/randomforest

pipe = Pipeline([('scaler', StandardScaler()), ('regr', RandomForestRegressor())])

# Parameter space:
max_features = ['sqrt']
n_estimators = [500,600,700,800]

param_grid = {'regr':[RandomForestRegressor()],
            'regr__max_features':max_features,
            'regr__n_estimators':n_estimators}

model = GridSearchCV(pipe, param_grid=param_grid, scoring='r2', verbose=50)

predictions = np.empty([data_features_test.index.unique().size,4])
predictions.shape

best_scores = []
m = 0
for vital in vitals:

    model.fit(X_3_train, data_labels_train[vital])
    predictions[:,m] = model.predict(X_3_test) 
    best_scores.append(model.best_score_)
    m = m+1

print(f'The mean r2-score is: {np.mean(best_scores)}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.430, total=  41.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   41.7s remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.449, total=  41.7s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.4min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.439, total=  41.5s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.1min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.407, total=  41.1s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.437, total=  41.7s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.5min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.428, total=  49.8s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  4.3min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.450, total=  50.2s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  5.1min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.440, total=  49.9s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  6.0min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.408, total=  49.6s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  6.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.437, total=  50.4s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  7.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.427, total=  58.4s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  8.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.450, total=  58.4s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  9.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.443, total=  58.5s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 10.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.407, total=  58.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 11.5min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.436, total=  58.4s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 12.5min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.431, total= 1.1min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 13.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.451, total= 1.1min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 14.7min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.442, total= 1.1min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 15.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.406, total= 1.1min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 16.9min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.437, total= 1.1min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 18.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 18.0min finished
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.629, total=  39.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   39.0s remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.621, total=  39.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.3min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.645, total=  39.1s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.0min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.639, total=  38.9s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=500, score=0.615, total=  38.6s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.2min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.630, total=  46.9s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  4.0min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.620, total=  46.6s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  4.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.645, total=  46.9s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  5.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.641, total=  46.6s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  6.4min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.616, total=  47.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  7.2min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.630, total=  55.4s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  8.1min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.620, total=  57.4s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  9.0min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.644, total=  55.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 10.0min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.640, total=  54.7s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 10.9min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.617, total=  54.5s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 11.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.628, total= 1.0min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 12.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.621, total= 1.0min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 13.9min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.644, total= 1.0min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 14.9min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.639, total= 1.0min
# ...
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.666, total=  48.8s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  5.8min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.670, total=  48.5s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  6.6min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=600, score=0.647, total=  48.2s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  7.4min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.670, total=  55.9s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  8.4min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.671, total=  55.7s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  9.3min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.667, total=  55.8s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 10.2min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.671, total=  56.4s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 11.2min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=700, score=0.648, total=  56.1s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 12.1min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.670, total= 1.1min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 13.2min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.671, total= 1.1min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 14.3min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.666, total= 1.1min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 15.3min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.672, total= 1.1min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 16.4min remaining:    0.0s
# [CV] regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800
# [CV]  regr=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False), regr__max_features=sqrt, regr__n_estimators=800, score=0.648, total= 1.1min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 17.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 17.5min finished
# The mean r2-score is: 0.531608881470806

# %%
predictions_fixed = predictions[:,0:4]
# Out:
# [[ 15.33147222  83.09596819  98.62266667  86.67726389]
#  [ 17.71851516  87.19916667  97.2205      93.508125  ]
#  [ 19.0175363   74.13116667  95.7065      71.414375  ]
#  ...
#  [ 18.61996591  77.72182828  98.4685      88.61475   ]
#  [ 19.79520833  93.20283333  97.25766667 108.3435    ]
#  [ 17.622625    81.96933333  98.9565     102.102375  ]]

# %%
submission_3 = pd.DataFrame(predictions_fixed, index=data_features_test.index.unique(), columns=data_labels_train[vitals].columns)
submission_3.head
# Out:
# <bound method NDFrame.head of        LABEL_RRate  LABEL_ABPm  LABEL_SpO2  LABEL_Heartrate
# pid
# 0        15.331472   83.095968   98.622667        86.677264
# 3        17.718515   87.199167   97.220500        93.508125
# 5        19.017536   74.131167   95.706500        71.414375
# 7        17.878000   88.410167   97.758833        93.804250
# 9        20.222583   88.494778   96.003167        91.343375
# ...            ...         ...         ...              ...
# 31647    16.548000   71.837833   97.135833        74.072500
# 31649    16.432042   84.257029   96.387037        91.508250
# 31651    18.619966   77.721828   98.468500        88.614750
# 31652    19.795208   93.202833   97.257667       108.343500
# 31655    17.622625   81.969333   98.956500       102.102375
#
# [12664 rows x 4 columns]>

# %%
subtask_1 = pd.read_csv('subtask_1.csv', index_col='pid')
subtask_2 = pd.read_csv('subtask_2.csv', index_col='pid')
submission = pd.concat((subtask_1, subtask_2, submission_3), axis=1)
submission.to_csv('prediction.zip', index=True, float_format='%.3f', compression='zip')
submission.to_csv('prediction.csv', index=True, float_format='%.3f')
